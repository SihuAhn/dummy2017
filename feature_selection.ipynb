# %%
from sklearn.datasets import load_breast_cancer #sklearn datasets의 유방암 진단 데이터 호출
cancer = load_breast_cancer()
X,y = cancer.data, cancer.target
X.shape
# Out:
# (569, 30)

# %%
#DecisionTree 기반 모델로 feature selection
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(random_state = 0).fit(X, y) #dtc 머신 생성
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# (569, 13)

# %%
#Perceptron 기반 모델
from sklearn.linear_model import Perceptron

pc = Perceptron(tol=1e-3, #tol 없이 실행시 에러메시지가 뜨고 tol의 기본값은 3이라고 안내해줌
                random_state=0).fit(X, y)
dtc = DecisionTreeClassifier(random_state = 0).fit(X, y) #dtc 머신 생성
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# (569, 13)

# %%
from sklearn.datasets import load_breast_cancer #sklearn datasets의 유방암 진단 데이터 호출
cancer = load_breast_cancer()

data = pd.DataFrame(np.c_[cancer["data"], cancer["target"]],
                    columns = np.append(cancer['feature_names'], ["target"]))

data_malignant=pd.DataFrame()
data_benign=pd.DataFrame()

for i in range(len(data)):
    if data.target[i] == 0.0:
        data_malignant.append()
    else:
        data_benign.append



X = data.drop(["target"], axis=1) #target을 제외한 feature들을 X에 저장
y = data["target"].astype(int) #target을 y에 저장


X_malignant = data_malignant.drop(["target"], axis=1)
y_malignant = data_malignant["target"].astype(int)

X_benign = data_benign.drop(["target"], axis=1)
y_benign = data_benign["target"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-a1ad9b3e3c11> in <module>
#      20
#      21
# ---> 22 X_malignant = data_malignant.drop(["target"], axis=1)
#      23 y_malignant = data_malignant["target"].astype(int)
#      24
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
# ...

# %%
from sklearn.datasets import load_breast_cancer #sklearn datasets의 유방암 진단 데이터 호출
cancer = load_breast_cancer()

data = pd.DataFrame(np.c_[cancer["data"], cancer["target"]],
                    columns = np.append(cancer['feature_names'], ["target"]))

# print(data)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from subprocess import check_output

from sklearn.datasets import load_breast_cancer #sklearn datasets의 유방암 진단 데이터 호출
cancer = load_breast_cancer()

data = pd.DataFrame(np.c_[cancer["data"], cancer["target"]],
                    columns = np.append(cancer['feature_names'], ["target"]))

X = data.drop(["target"], axis=1) #target을 제외한 feature들을 X에 저장
y = data["target"].astype(int) #target을 y에 저장


ax = sns.countplot(y,label="Count")       # M = 212, B = 357
B, M = y.value_counts()
print('Number of Benign: ',B)
print('Number of Malignant : ',M)
# Out:
# Number of Benign:  357
# Number of Malignant :  212

# %%
from sklearn.datasets import load_breast_cancer #sklearn datasets의 유방암 진단 데이터 호출
cancer = load_breast_cancer()

df = pd.DataFrame(np.c_[cancer["data"], cancer["target"]],
                    columns = np.append(cancer['feature_names'], ["target"]))
X = data.drop(["target"], axis=1) #target을 제외한 feature들을 X에 저장
y = data["target"].astype(int) #target을 y에 저장

sy = pd.Series(cancer.target, dtype="category")
sy = sy.cat.rename_categories(cancer.target_names)
df['class'] = sy

import seaborn as sns
sns.pairplot(vars=['mean radius', 'mean texture', 'mean perimeter', 'mean area',
 'mean smoothness', 'mean compactness', 'mean concavity',
 'mean concave points', 'mean symmetry', 'mean fractal dimension'], 
             hue="class", data=df)
plt.show()

# %%
print(cancer.feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
sns.pairplot(vars=[
 'radius error', 'texture error', 'perimeter error', 'area error',
 'smoothness error', 'compactness error', 'concavity error',
 'concave points error', 'symmetry error', 'fractal dimension error',
], 
             hue="class", data=df)
plt.show()

# %%
 sns.pairplot(vars=['worst radius', 'worst texture', 'worst perimeter', 'worst area',
 'worst smoothness', 'worst compactness', 'worst concavity',
 'worst concave points', 'worst symmetry', 'worst fractal dimension'], 
             hue="class", data=df)
plt.show()
